# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
# Define parameters
params = {
    'q': 'love',
    'fq': filter_query,
    'sort': sort,
    'fl': field_list,
    'begin_date': begin_date,
    'end_date': end_date,
    'api-key': nyt_api_key
}

# Make the request
response = requests.get(url, params=params)

# Print the URL to check correctness
print(response.url)

# Get the JSON response
data = response.json()
# Out:
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=love&fq=section_name%3A%22Movies%22+AND+type_of_material%3A%22Review%22+AND+headline%3A%22love%22&sort=newest&fl=headline%2Cweb_url%2Csnippet%2Csource%2Ckeywords%2Cpub_date%2Cbyline%2Cword_count&begin_date=20130101&end_date=20230531&api-key=XkNrFpO4HXWcnGTAkB1yY0TCUhYAhGsA

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19
for page in range(20):
    # Define parameters
    # create query with a page number
    # API results show 10 articles at a time

    params = {
        'q': 'love',
        'fq': filter_query,
        'sort': sort,
        'fl': field_list,
        'begin_date': begin_date,
        'end_date': end_date,
        'page': page,
        'api-key': nyt_api_key
    }
    
    # Make a "GET" request and retrieve the JSON
    try:
        response = requests.get(url, params=params)
        data = response.json()
# Add a twelve second interval between queries to stay within API query limits
        time.sleep(12)
     
    # Try and save the reviews to the reviews_list
        if 'response' in data and 'docs' in data['response']:
            docs = data['response']['docs']


        # loop through the reviews["response"]["docs"] and append each review to the list
            for review in docs:
                reviews_list.append(review)
        # Print the page that was just retrieved
            print(f"Page {page} retrieved successfully.")

        # Print the page number that had no results then break from the loop
        if not docs:
            print(f"Page {page} had no results. Breaking loop.")
            break
#error handling
    except Exception as e:
        print(f"An error occurred on page {page}: {e}")
# Out:
# Page 0 retrieved successfully.
# Page 1 retrieved successfully.
# Page 2 retrieved successfully.
# Page 3 retrieved successfully.
# Page 4 retrieved successfully.
# Page 5 retrieved successfully.
# Page 6 retrieved successfully.
# Page 7 retrieved successfully.
# Page 8 retrieved successfully.
# Page 9 retrieved successfully.
# Page 10 retrieved successfully.
# Page 11 retrieved successfully.
# Page 12 retrieved successfully.
# Page 13 retrieved successfully.
# Page 14 retrieved successfully.
# Page 15 retrieved successfully.
# Page 16 retrieved successfully.
# Page 17 retrieved successfully.
# Page 18 retrieved successfully.
# Page 19 retrieved successfully.

# %%
# Preview the first 5 results in JSON format
first_5_reviews = reviews_list[:5]
# Use json.dumps with argument indent=4 to format data
formatted_json = json.dumps(first_5_reviews, indent=4)
print(formatted_json)
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Diment, Valentin Javier",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-25T11:00:03+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 295
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html",
#         "snippet": "Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018What\u2019s Love Got to Do With It?\u2019 Probably a Lot",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "What\u2019s Love Got to Do With It?",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kapur, Shekhar",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "James, Lily",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Azmi, Shabana",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Thompson, Emma",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T17:16:45+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 287
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html",
#         "snippet": "Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018You Can Live Forever\u2019 Review: Do You Love Me Now?",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "You Can Live Forever",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "You Can Live Forever (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Slutsky, Mark",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Watts, Sarah (Film Director)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "O'Driscoll, Anwen",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Laporte, June (Actor)",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T11:00:08+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 294
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/21/movies/a-tourists-guide-to-love-review.html",
#         "snippet": "Rachael Leigh Cook stars in this bland rom-com as a travel executive exploring Vietnam and getting over a breakup.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018A Tourist\u2019s Guide to Love\u2019 Review: A Wearyingly Familiar Trip",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Tourist\u2019s  Guide to Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "A Tourist's Guide to Love (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Tsuchida, Steven",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Cook, Rachael Leigh",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-21T07:03:25+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 276
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/20/movies/other-peoples-children-review.html",
#         "snippet": "A radiant Virginie Efira stars as a Parisian teacher who blissfully falls for a man and his 4-year-old daughter, complicating everyone\u2019s lives.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Other People\u2019s Children\u2019 Review: True Romance",
#             "kicker": "Critic\u2019s pick",
#             "content_kicker": null,
#             "print_headline": "Intoxicating Love With a Sobering Turn",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Zlotowski, Rebecca",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Other People's Children (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-20T15:35:13+0000",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 801
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
from pandas import json_normalize
df_reviews = json_normalize(reviews_list)
print(df_reviews.head())
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T17:16:45+0000         287
# 2  2023-05-04T11:00:08+0000         294
# 3  2023-04-21T07:03:25+0000         276
# 4  2023-04-20T15:35:13+0000         801
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4     ‘Other People’s Children’ Review: True Romance   Critic’s pick
#
#   headline.content_kicker                 headline.print_headline  \
# 0                    None                  The Attachment Diaries
# 1                    None          What’s Love Got to Do With It?
# 2                    None                    You Can Live Forever
# 3                    None              A Tourist’s  Guide to Love
# 4                    None  Intoxicating Love With a Sobering Turn
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None    By Jeannette Catsoulis
# 2          None         None         None  By Elisabeth Vincentelli
# 3          None         None         None  By Elisabeth Vincentelli
# 4          None         None         None         By Manohla Dargis
#
#                                        byline.person byline.organization
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None

# %%
# Extract the title from the "headline.main" column and
df_reviews['title'] = df_reviews['headline.main'].apply(
    lambda st: st[st.find("\u2018")+1:st.find("\u2019")] + " Review"
    if "\u2019" in st and not st[st.find("\u2018")+1:st.find("\u2019")].endswith(" Review")
    else st[st.find("\u2018")+1:st.find("\u2019")]
)
# Extract the title between \u2018 and \u2019
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
  
# End string should include " Review" to avoid cutting title early
print(df_reviews[['headline.main', 'title']].head())
# Out:
#                                        headline.main  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...
# 4     ‘Other People’s Children’ Review: True Romance
#
#                            title
# 0  The Attachment Diaries Review
# 1                    What Review
# 2    You Can Live Forever Review
# 3               A Tourist Review
# 4            Other People Review

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
df_reviews['keywords'] = df_reviews['keywords'].apply(extract_keywords)
print(df_reviews[['keywords']].head())
# Out:
#                                             keywords
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;persons: Kapur, Shekhar;person...
# 2  subject: Movies;creative_works: You Can Live F...
# 3  subject: Movies;creative_works: A Tourist's Gu...
# 4  subject: Movies;persons: Zlotowski, Rebecca;cr...

# %%
# Create a list from the "title" column using to_list()
title_list = df_reviews['title'].to_list()
# These titles will be used in the query for The Movie Database
print(title_list)
# Out:
# ['The Attachment Diaries Review', 'What Review', 'You Can Live Forever Review', 'A Tourist Review', 'Other People Review', 'One True Loves Review', 'The Lost Weekend: A Love Story Review', 'A Thousand and One Review', 'Your Place or Mine Review', 'Love in the Time of Fentanyl Review', 'Pamela, a Love Story Review', 'In From the Side Review', 'After Love Review', 'Alcarràs Review', 'Nelly & Nadine Review', 'Lady Chatterley Review', 'The Sound of Christmas Review', 'The Inspection Review', 'Bones and All Review', 'My Policeman Review', 'About Fate Review', 'Waiting for Bojangles Review', 'I Love My Dad Review', 'A Love Song Review', 'Alone Together Review', 'Art of Love Review', 'The Wheel Review', 'Thor: Love and Thunder Review', 'Both Sides of the Blade Review', 'Fire of Love Review', 'Love & Gelato Review', 'Stay Prayed Up Review', 'Benediction Review', 'Dinner in America Review', 'In a New York Minute Review', 'Anaïs in Love Review', 'I Love America Review', 'See You Then Review', 'La Mami Review', 'Love After Love Review', 'Deep Water Review', 'Lucy and Desi Review', 'Cyrano Review', 'The In Between Review', 'Book of Love Review', 'Lingui, the Sacred Bonds Review', 'The Pink Cloud Review', 'A Journal for Jordan Review', 'West Side Story Review', 'Aulcie Review', 'Love Is Love Is Love Review', 'Love Hard Review', 'Bergman Island Review', 'Hard Luck Love Song Review', 'South of Heaven Review', 'Wife of a Spy Review', 'Happier Than Ever Review', 'Together Review', 'Annette Review', 'Resort to Love Review', 'Woodstock 99: Peace, Love and Rage Review', 'Casanova, Last Love Review', 'Running Against the Wind Review', 'Asia Review', 'Undine Review', 'This Town Review', 'Tu Me Manques Review', 'Monday Review', 'Ride or Die Review', 'Future People Review', 'Luz Review', 'Happily Review', 'This Is the Life Review', 'To All the Boys: Always and Forever Review', 'Young Hearts Review', 'Little Fish Review', 'Two of Us Review', 'Atlantis Review', 'Preparations to Be Together Review', 'Your Name Engraved Herein Review', 'Sylvie Review', 'Ariana Grande: Excuse Me, I Love You Review', 'Museum Town Review', 'Wild Mountain Thyme Review', 'My Psychedelic Love Story Review', '69: The Saga of Danny Hernandez Review', 'Ammonite Review', 'Love and Monsters Review', 'Dick Johnson Is Dead Review', 'Love, Guaranteed Review', 'Feel the Beat Review', 'Babyteeth Review', 'Spelling the Dream Review', 'A Secret Love Review', 'Love Wedding Repeat Review', 'Almost Love Review', 'Hope Gap Review', 'All the Bright Places Review', 'The Photograph Review', 'You Go to My Head Review', 'Ordinary Love Review', 'To All the Boys: P.S. I Still Love You Review', 'The Woman Who Loves Giraffes Review', 'Queen & Slim Review', 'Marriage Story Review', 'Cyrano, My Love Review', 'Pretenders Review', 'First Love Review', 'Loro Review', 'Falling Inn Love Review', 'Hot Air Review', 'Love, Antosha Review', 'Leto Review', 'The Tomorrow Man Review', 'Asako I & II Review', 'The Sun Is Also a Star Review', 'Shéhérazade Review', 'Long Shot Review', 'Clara Review', 'Kalank Review', 'Rafiki Review', 'Diane Review', 'Five Feet Apart Review', 'Ash Is Purest White Review', 'Gloria Bell Review', 'Black Mother Review', 'The Hole in the Ground Review', 'How to Train Your Dragon: The Hidden World Review', 'A Tuba to Cuba Review', 'Fighting With My Family Review', 'Sorry Angel Review', 'Berlin, I Love You Review', 'Untogether Review', 'Cold War Review', 'If Beale Street Could Talk Review', 'Asher Review', 'The Party Review', 'The Great Pretender Review', 'Sicilian Ghost Story Review', 'The New Romantic Review', 'Pimp Review', 'In a Relationship Review', 'They Review', 'Burning, Review', 'After Everything, Review', 'Quincy Review', 'Love, Gilda, Review', 'Tea With the Dames, Review', 'Bel Canto, Review', 'The Citizen, Review', 'Love, Cecil, Review', 'How to Talk to Girls at Parties Review', 'Rogers Park, Review', 'Love & Bananas, Review', ' Review', 'Submergence, Review', 'Love After Love, Rev ...

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
# Create an empty list to store the results
tmdb_movies_list = []

# Create a request counter to sleep the requests after a multiple
request_counter = 0

# of 50 requests
max_requests_before_sleep = 50

# Loop through the titles
for title in title_list:
    # Check if we need to sleep before making a request
    if request_counter > 0 and request_counter % max_requests_before_sleep == 0:
        print("Sleeping to avoid hitting the rate limit...")
        time.sleep(10)  # Sleep for 10 seconds (or longer if needed)
    
    # Add 1 to the request counter
    request_counter += 1
    
    # Perform a "GET" request for The Movie Database
    try:
        search_url = f"https://api.themoviedb.org/3/search/movie?query={title}&api_key={tmdb_api_key}"
        response = requests.get(search_url)
        search_data = response.json()

        # Include a try clause to search for the full movie details.
        if 'results' in search_data and search_data['results']:
            try:
                # Get movie id
                movie_id = search_data['results'][0]['id']

                # Make a request for the full movie details
                details_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb_api_key}"

                # Execute "GET" request with url
                details_response = requests.get(details_url)
                details_data = details_response.json()
                
                # Extract the genre names into a list
                genres = [genre['name'] for genre in details_data.get('genres', [])]

                # Extract the spoken_languages' English name into a list
                spoken_languages = [lang['english_name'] for lang in details_data.get('spoken_languages', [])]

                # Extract the production_countries' name into a list
                production_countries = [country['name'] for country in details_data.get('production_countries', [])]

                # Add the relevant data to a dictionary and
                movie_details = {
                    'title': title,
                    'original_title': details_data.get('original_title'),
                    'budget': details_data.get('budget'),
                    'original_language': details_data.get('original_language'),
                    'homepage': details_data.get('homepage'),
                    'overview': details_data.get('overview'),
                    'popularity': details_data.get('popularity'),
                    'runtime': details_data.get('runtime'),
                    'revenue': details_data.get('revenue'),
                    'release_date': details_data.get('release_date'),
                    'vote_average': details_data.get('vote_average'),
                    'vote_count': details_data.get('vote_count'),
                    'genres': genres,
                    'spoken_languages': spoken_languages,
                    'production_countries': production_countries
                }
                
                # append it to the results_list list
                tmdb_movies_list.append(movie_details)
                
                # Print out the title that was found
                print(f"Found and added: {title}")
            
            except Exception as e:
                print(f"Failed to retrieve full details for {title}: {e}")
        else:
            print(f"Movie not found: {title}")
    
    except Exception as e:
        print(f"An error occurred while searching for {title}: {e}")
# Out:
# Movie not found: The Attachment Diaries Review
# Movie not found: What Review
# Movie not found: You Can Live Forever Review
# Movie not found: A Tourist Review
# Movie not found: Other People Review
# Movie not found: One True Loves Review
# Movie not found: The Lost Weekend: A Love Story Review
# Movie not found: A Thousand and One Review
# Movie not found: Your Place or Mine Review
# Movie not found: Love in the Time of Fentanyl Review
# Movie not found: Pamela, a Love Story Review
# Movie not found: In From the Side Review
# Movie not found: After Love Review
# Movie not found: Alcarràs Review
# Found and added: Nelly & Nadine Review
# Movie not found: Lady Chatterley Review
# Movie not found: The Sound of Christmas Review
# Movie not found: The Inspection Review
# Movie not found: Bones and All Review
# Movie not found: My Policeman Review
# Movie not found: About Fate Review
# Movie not found: Waiting for Bojangles Review
# Movie not found: I Love My Dad Review
# Movie not found: A Love Song Review
# Movie not found: Alone Together Review
# Movie not found: Art of Love Review
# Movie not found: The Wheel Review
# Movie not found: Thor: Love and Thunder Review
# Movie not found: Both Sides of the Blade Review
# Movie not found: Fire of Love Review
# Found and added: Love & Gelato Review
# Movie not found: Stay Prayed Up Review
# Movie not found: Benediction Review
# Movie not found: Dinner in America Review
# Movie not found: In a New York Minute Review
# Movie not found: Anaïs in Love Review
# Movie not found: I Love America Review
# Movie not found: See You Then Review
# Movie not found: La Mami Review
# Movie not found: Love After Love Review
# Movie not found: Deep Water Review
# Movie not found: Lucy and Desi Review
# Movie not found: Cyrano Review
# Movie not found: The In Between Review
# Movie not found: Book of Love Review
# Movie not found: Lingui, the Sacred Bonds Review
# Movie not found: The Pink Cloud Review
# Movie not found: A Journal for Jordan Review
# Movie not found: West Side Story Review
# Movie not found: Aulcie Review
# Sleeping to avoid hitting the rate limit...
# Movie not found: Love Is Love Is Love Review
# Movie not found: Love Hard Review
# Movie not found: Bergman Island Review
# Movie not found: Hard Luck Love Song Review
# Movie not found: South of Heaven Review
# Movie not found: Wife of a Spy Review
# Movie not found: Happier Than Ever Review
# Found and added: Together Review
# Movie not found: Annette Review
# Movie not found: Resort to Love Review
# Movie not found: Woodstock 99: Peace, Love and Rage Review
# Movie not found: Casanova, Last Love Review
# Movie not found: Running Against the Wind Review
# Found and added: Asia Review
# Movie not found: Undine Review
# Movie not found: This Town Review
# Movie not found: Tu Me Manques Review
# Movie not found: Monday Review
# Movie not found: Ride or Die Review
# Movie not found: Future People Review
# Movie not found: Luz Review
# Movie not found: Happily Review
# Movie not found: This Is the Life Review
# Movie not found: To All the Boys: Always and Forever Review
# Movie not found: Young Hearts Review
# Movie not found: Little Fish Review
# Movie not found: Two of Us Review
# Movie not found: Atlantis Review
# Movie not found: Preparations to Be Together Review
# Movie not found: Your Name Engraved Herein Review
# Movie not found: Sylvie Review
# Movie not found: Ariana Grande: Excuse Me, I Love You Review
# Movie not found: Museum Town Review
# Movie not found: Wild Mountain Thyme Review
# Movie not found: My Psychedelic Love Story Review
# Movie not found: 69: The Saga of Danny Hernandez Review
# Movie not found: Ammonite Review
# Movie not found: Love and Monsters Review
# Movie not found: Dick Johnson Is Dead Review
# Movie not found: Love, Guaranteed Review
# Movie not found: Feel the Beat Review
# Movie not found: Babyteeth Review
# Movie not found: Spelling the Dream Review
# Movie not found: A Secret Love Review
# Movie not found: Love Wedding Repeat Review
# Movie not found: Almost Love Review
# Movie not found: Hope Gap Review
# Movie not found: All the Bright Places Review
# Movie not found: The Photograph Review
# Movie not found: You Go to My Head Review
# Sleeping to avoid hitting the rate limit...
# Movie not found: Ordinary Love Review
# Movie not found: To All the Boys: P.S. I Still Love You Review
# Movie not found: The Woman Who Loves Giraffes Review
# Found and added: Queen & Slim Review
# Movie not found: Marriage Story Review
# Movie not found: Cyrano, My Love Review
# Movie not found: Pretenders Review
# Movie not found: First Love Review
# Movie not found: Loro Review
# Movie not found: Falling Inn Love Review
# Movie not found: Hot Air Review
# Movie not found: Love, Antosha Review
# Movie not found: Leto Review
# Movie not found: The Tomorrow Man Review
# Found and added: Asako I & II Review
# Movie not found: The Sun Is Also a Star Review
# Movie not found: Shéhérazade Review
# Movie not found: Long Shot Review
# Movie not found: Clara Review
# Movie not found: Kalank Review
# Movie not found: Rafiki Review
# Movie not found: Diane Review
# Movie not found: Five Feet Apart Review
# Movie not found: Ash Is Purest White Review
# Movie not found: Gloria Bell Review
# Movie not found: Black Mother Review
# Movie not found: The Hole in the Ground Review
# Movie not found: How to Train Your Dragon: The Hidden World Review
# Movie not found: A Tuba to Cuba Review
# Movie not found: Fighting With My Family Review
# Movie not found: Sorry Angel Review
# Movie not found: Berlin, I Love You Review
# Movie not found: Untogether Review
# Movie not found: Cold War Review
# Movie not found: If Beale Street Could Talk Review
# Movie not found: Asher Review
# Movie not found: The Party Review
# Movie not found: The Great Pretender Review
# Movie not found: Sicilian Ghost Story Review
# Movie not found: The New Romantic Review
# Movie not found: Pimp Review
# Movie not found: In a Relationship Review
# Found and added: They Review
# Movie not found: Burning, Review
# Movie not found: After Everything, Review
# Movie not found: Quincy Review
# Movie not found: Love, Gilda, Review
# Movie not found: Tea With the Dames, Review
# Movie not found: Bel Canto, Review
# Movie not found: The Citizen, Review
# Sleeping to avoid hitting the rate limit...
# Movie not found: Love, Cecil, Review
# Movie not found: How to Talk to Girls at Parties Review
# Movie not found: Rogers Park, Review
# Found and added: Love & Bananas, Review
# Found and added:  Review
# Movie not found: Submergence, Review
# Movie not found: Love After Love, Review
# Movie not found: Outside In Review
# Movie not found: Love, Simon, Review
# Movie not found: Keep the Change, Review
# Movie not found: The Party Review
# Movie not found: The Housemaid, Review
# Movie not found: Forever My Girl, Review
# Movie not found: Kangaroo: A Love-Hate Story Review
# Movie not found: Lover for a Day Review
# Movie not found: Youth, Review
# Movie not found: Killing for Love Review
# Movie not found: The Shape of Water Review
# Movie not found: Love Beats Rhymes, Review
# Movie not found: Cuba and the Cameraman Review
# Movie not found: On the Beach at Night Alone Review
# Movie not found: Thelma, Review
# Movie not found: Hello Again, Review
# Movie not found: It Happened in L.A., Review
# Movie not found: God Review
# Movie not found: The Mountain Between Us Review
# Movie not found: Dina, Review
# Movie not found: In Search of Fellini Review
# Movie not found: Woodpeckers, Review
# Movie not found: I Do ... Until I Don Review
# Movie not found: Tales of an Immoral Couple Review
# Movie not found: After Love Review
# Found and added:  Review
# Movie not found: Women Who Kill, Review
# Movie not found: False Confessions, Review
# Movie not found: Review: Those Movies, Himself — Bertrand Tavernier Review
# Movie not found: The Big Sick, Review
# Movie not found: Lost in Paris Review
# Movie not found: Vincent N Roxxy, Review
# Movie not found: Everything, Everything Review
# Found and added: Hounds of Love Review
# Movie not found: Harold and Lillian Review
# Movie not found: The Happiest Day in the Life of Olli Maki, Review
# Movie not found: The Promise Review
# Movie not found: Frantz, Review
# Movie not found: The Other Half Review
# Movie not found: The Ottoman Lieutenant Review
# Found and added:  Review
# Movie not found: Everybody Loves Somebody, Review
# Movie not found: Kedi, Review

# %%
print(tmdb_movies_list)
# Out:
# [{'title': 'Nelly & Nadine Review', 'original_title': 'Nelly Knows Mysteries: A Fatal Engagement', 'budget': 0, 'original_language': 'en', 'homepage': 'https://www.hallmarkmystery.com/nelly-knows-mysteries-a-fatal-engagement', 'overview': 'When an unusual handwritten letter arrives at Nelly’s office, she identifies the handwriting as belonging to her childhood friend Dahlia, claiming her boyfriend Blake is being unfaithful. Determined to help, Nelly wants some answers and rushes to Blake’s home only to find his dead body. When Dahlia becomes the prime suspect, the new, handsome Detective in town, Michael Hogan must work with Nelly to prove that her childhood friend is not the killer everyone believes her to be.', 'popularity': 11.516, 'runtime': 84, 'revenue': 0, 'release_date': '2024-08-23', 'vote_average': 7.667, 'vote_count': 2, 'genres': ['Comedy', 'Mystery', 'TV Movie'], 'spoken_languages': ['English'], 'production_countries': []}, {'title': 'Love & Gelato Review', 'original_title': 'Mektoub, My Love: Canto Uno', 'budget': 0, 'original_language': 'fr', 'homepage': 'https://www.pathefilms.com/film/mektoubmylovecantouno', 'overview': "Amin, an aspiring screenwriter living in Paris, returns home for the summer, to a fishing village in the South of France. It is a time of reconnecting with his family and his childhood friends. Together with his cousin Tony and his best friend Ophélie, he spends his time between the Tunisian restaurant run by his parents, the local bars and the beaches frequented by girls on holiday. Enchanted by the many female characters who surround him, Amin remains in awe of these summer sirens while his dionysiac cousin throws himself into their carnal delights with euphoria. Armed with his camera and guided by the bright simmer light of the Mediterranean coast, Amin pursues his philosophical quest while gathering inspiration for his screenplays. When it comes to love, only Mektoub (‘destiny' in Arabic) can decide.", 'popularity': 14.96, 'runtime': 181, 'revenue': 1200387, 'release_date': '2017-09-07', 'vote_average': 6.709, 'vote_count': 297, 'genres': ['Romance', 'Drama'], 'spoken_languages': ['Arabic', 'English', 'French'], 'production_countries': ['France', 'Italy']}, {'title': 'Together Review', 'original_title': 'Putting It Together', 'budget': 0, 'original_language': 'en', 'homepage': '', 'overview': 'An all-star cast performs the music of one of the greatest composers of our time... Stephen Sondheim.  Anxiously anticipated by the myriad fans of the legendary composer, Putting It Together marked the return of Carol Burnett to the Broadway musical stage for the first time in over 35 years.  Stephen Sondheim has won a record seven Tony Awards for his songwriting, and the Pulitzer Prize for Sunday in the Park with George.  His Broadway smash shows and movies include Gypsy, A Funny Thing Happened on the Way to the Forum, Sweeney Todd, Dick Tracy, and West Side Story.  This Cameron Mackintosh stage production was captured live in performance during its Broadway run and recorded in high definition with a widescreen format using ten cameras and over 40 microphones.', 'popularity': 2.657, 'runtime': 105, 'revenue': 0, 'release_date': '2001-10-14', 'vote_average': 5.8, 'vote_count': 6, 'genres': ['Drama', 'Comedy'], 'spoken_languages': ['English'], 'production_countries': ['United States of America']}, {'title': 'Asia Review', 'original_title': 'Asia: Music in Review', 'budget': 0, 'original_language': 'en', 'homepage': '', 'overview': 'Pop-rock supergroup Asia is the focus of this critical review that traces the band\'s origins and highlights their musical achievements. Featuring former members of rock groups Yes, King Crimson and Emerson, Lake &amp; Palmer, Asia rose to the top of charts in the 1980s with hits such as "Heat of the Moment" and "Sole Survivor." This video features live performances of many Asia favorites, along with exclusive interviews with band members.', 'popularity': 0.001, 'runtime':  ...

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
json_preview = json.dumps(tmdb_movies_list[:5], indent=4)
print(json_preview)
# Out:
# [
#     {
#         "title": "Nelly & Nadine Review",
#         "original_title": "Nelly Knows Mysteries: A Fatal Engagement",
#         "budget": 0,
#         "original_language": "en",
#         "homepage": "https://www.hallmarkmystery.com/nelly-knows-mysteries-a-fatal-engagement",
#         "overview": "When an unusual handwritten letter arrives at Nelly\u2019s office, she identifies the handwriting as belonging to her childhood friend Dahlia, claiming her boyfriend Blake is being unfaithful. Determined to help, Nelly wants some answers and rushes to Blake\u2019s home only to find his dead body. When Dahlia becomes the prime suspect, the new, handsome Detective in town, Michael Hogan must work with Nelly to prove that her childhood friend is not the killer everyone believes her to be.",
#         "popularity": 11.516,
#         "runtime": 84,
#         "revenue": 0,
#         "release_date": "2024-08-23",
#         "vote_average": 7.667,
#         "vote_count": 2,
#         "genres": [
#             "Comedy",
#             "Mystery",
#             "TV Movie"
#         ],
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": []
#     },
#     {
#         "title": "Love & Gelato Review",
#         "original_title": "Mektoub, My Love: Canto Uno",
#         "budget": 0,
#         "original_language": "fr",
#         "homepage": "https://www.pathefilms.com/film/mektoubmylovecantouno",
#         "overview": "Amin, an aspiring screenwriter living in Paris, returns home for the summer, to a fishing village in the South of France. It is a time of reconnecting with his family and his childhood friends. Together with his cousin Tony and his best friend Oph\u00e9lie, he spends his time between the Tunisian restaurant run by his parents, the local bars and the beaches frequented by girls on holiday. Enchanted by the many female characters who surround him, Amin remains in awe of these summer sirens while his dionysiac cousin throws himself into their carnal delights with euphoria. Armed with his camera and guided by the bright simmer light of the Mediterranean coast, Amin pursues his philosophical quest while gathering inspiration for his screenplays. When it comes to love, only Mektoub (\u2018destiny' in Arabic) can decide.",
#         "popularity": 14.96,
#         "runtime": 181,
#         "revenue": 1200387,
#         "release_date": "2017-09-07",
#         "vote_average": 6.709,
#         "vote_count": 297,
#         "genres": [
#             "Romance",
#             "Drama"
#         ],
#         "spoken_languages": [
#             "Arabic",
#             "English",
#             "French"
#         ],
#         "production_countries": [
#             "France",
#             "Italy"
#         ]
#     },
#     {
#         "title": "Together Review",
#         "original_title": "Putting It Together",
#         "budget": 0,
#         "original_language": "en",
#         "homepage": "",
#         "overview": "An all-star cast performs the music of one of the greatest composers of our time... Stephen Sondheim.  Anxiously anticipated by the myriad fans of the legendary composer, Putting It Together marked the return of Carol Burnett to the Broadway musical stage for the first time in over 35 years.  Stephen Sondheim has won a record seven Tony Awards for his songwriting, and the Pulitzer Prize for Sunday in the Park with George.  His Broadway smash shows and movies include Gypsy, A Funny Thing Happened on the Way to the Forum, Sweeney Todd, Dick Tracy, and West Side Story.  This Cameron Mackintosh stage production was captured live in performance during its Broadway run and recorded in high definition with a widescreen format using ten cameras and over 40 microphones.",
#         "popularity": 2.657,
#         "runtime": 105,
#         "revenue": 0,
#         "release_date": "2001-10-14",
#         "vote_average": 5.8,
#         "vote_count": 6,
#         "genres": [
#             "Drama",
#             "Comedy"
#         ],
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Asia Review",
#         "original_title": "Asia: Music in Review",
#         "budget": 0,
#         "original_language": "en",
#         "homepage": "",
#         "overview": "Pop-rock supergroup Asia is the focus of this critical review that traces the band's origins and highlights their musical achievements. Featuring former members of rock groups Yes, King Crimson and Emerson, Lake &amp; Palmer, Asia rose to the top of charts in the 1980s with hits such as \"Heat of the Moment\" and \"Sole Survivor.\" This video features live performances of many Asia favorites, along with exclusive interviews with band members.",
#         "popularity": 0.001,
#         "runtime": 0,
#         "revenue": 0,
#         "release_date": "2006-01-01",
#         "vote_average": 0.0,
#         "vote_count": 0,
#         "genres": [],
#         "spoken_languages": [],
#         "production_countries": []
#     },
#     {
#         "title": "Queen & Slim Review",
#         "original_title": "\u0397 \u039c\u03b1\u03cd\u03c1\u03b7 \u0395\u03bc\u03bc\u03b1\u03bd\u03bf\u03c5\u03ad\u03bb\u03b1",
#         "budget": 0,
#         "original_language": "el",
#         "homepage": "",
#         "overview": "A woman struggles to keep her stepdaughter from harms way after she hires an assassin to kill her husband, but the hitman turns and blackmails her for the crime.",
#         "popularity": 41.432,
#         "runtime": 91,
#         "revenue": 0,
#         "release_date": "1980-02-01",
#         "vote_average": 6.119,
#         "vote_count": 88,
#         "genres": [
#             "Crime",
#             "Drama",
#             "Thriller"
#         ],
#         "spoken_languages": [
#             "Greek",
#             "Italian"
#         ],
#         "production_countries": [
#             "Cyprus",
#             "Greece"
#         ]
#     }
# ]

# %%
# Convert the results to a DataFrame
tmdb_df = pd.DataFrame(tmdb_movies_list)
print(tmdb_df.head())
# Out:
#                    title                             original_title  budget  \
# 0  Nelly & Nadine Review  Nelly Knows Mysteries: A Fatal Engagement       0
# 1   Love & Gelato Review                Mektoub, My Love: Canto Uno       0
# 2        Together Review                        Putting It Together       0
# 3            Asia Review                      Asia: Music in Review       0
# 4    Queen & Slim Review                         Η Μαύρη Εμμανουέλα       0
#
#   original_language                                           homepage  \
# 0                en  https://www.hallmarkmystery.com/nelly-knows-my...
# 1                fr  https://www.pathefilms.com/film/mektoubmylovec...
# 2                en
# 3                en
# 4                el
#
#                                             overview  popularity  runtime  \
# 0  When an unusual handwritten letter arrives at ...      11.516       84
# 1  Amin, an aspiring screenwriter living in Paris...      14.960      181
# 2  An all-star cast performs the music of one of ...       2.657      105
# 3  Pop-rock supergroup Asia is the focus of this ...       0.001        0
# 4  A woman struggles to keep her stepdaughter fro...      41.432       91
#
#    revenue release_date  vote_average  vote_count  \
# 0        0   2024-08-23         7.667           2
# 1  1200387   2017-09-07         6.709         297
# 2        0   2001-10-14         5.800           6
# 3        0   2006-01-01         0.000           0
# 4        0   1980-02-01         6.119          88
#
#                         genres           spoken_languages  \
# 0  [Comedy, Mystery, TV Movie]                  [English]
# 1             [Romance, Drama]  [Arabic, English, French]
# 2              [Drama, Comedy]                  [English]
# 3                           []                         []
# 4     [Crime, Drama, Thriller]           [Greek, Italian]
#
#          production_countries
# 0                          []
# 1             [France, Italy]
# 2  [United States of America]
# 3                          []
# 4            [Cyprus, Greece]

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
df_merged = pd.merge(df_reviews, tmdb_df, on='title', how='inner')
df_merged.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2022/12/15/movies/nell...
# 1  https://www.nytimes.com/2022/06/22/movies/love...
# 2  https://www.nytimes.com/2021/08/26/movies/toge...
# 3  https://www.nytimes.com/2021/06/10/movies/asia...
# 4  https://www.nytimes.com/2019/11/26/movies/quee...
#
#                                              snippet              source  \
# 0  A family archive provides intimate records of ...  The New York Times
# 1  A mother’s final wish leads her daughter to re...  The New York Times
# 2  Sharon Horgan and James McAvoy play a battling...  The New York Times
# 3  This drama about a young single mother and a t...  The New York Times
# 4  Daniel Kaluuya and Jodie Turner-Smith star in ...  The New York Times
#
#                                             keywords  \
# 0  subject: Documentary Films and Programs;person...
# 1  subject: Movies;creative_works: Love & Gelato ...
# 2  subject: Movies;creative_works: Together (Movi...
# 3  subject: Movies;persons: Haas, Shira;persons: ...
# 4  subject: Movies;creative_works: Queen & Slim (...
#
#                    pub_date  word_count  \
# 0  2022-12-15T12:00:04+0000         308
# 1  2022-06-23T03:06:01+0000         288
# 2  2021-08-26T11:00:06+0000         412
# 3  2021-06-10T11:00:15+0000         290
# 4  2019-11-26T17:41:50+0000         799
#
#                                        headline.main headline.kicker  \
# 0  ‘Nelly & Nadine’ Review: An Unlikely Love, an ...            None
# 1  ‘Love & Gelato’ Review: A Young Girl, Transfig...            None
# 2     ‘Together’ Review: Love and Loathing in London            None
# 3  ‘Asia’ Review: Tough Love and an Indecent Prop...            None
# 4             ‘Queen & Slim’ Review: Love on the Run   critic’s pick
#
#   headline.content_kicker                 headline.print_headline  ...  \
# 0                    None                      Nelly &amp; Nadine  ...
# 1                    None                       Love &amp; Gelato  ...
# 2                    None  Love and Loathing in a Blighted London  ...
# 3                    None                                    Asia  ...
# 4                    None          Love Simmers Inside a Cauldron  ...
#
#                                             overview popularity runtime  \
# 0  When an unusual handwritten letter arrives at ...     11.516      84
# 1  Amin, an aspiring screenwriter living in Paris...     14.960     181
# 2  An all-star cast performs the music of one of ...      2.657     105
# 3  Pop-rock supergroup Asia is the focus of this ...      0.001       0
# 4  A woman struggles to keep her stepdaughter fro...     41.432      91
#
#    revenue release_date vote_average vote_count                       genres  \
# 0        0   2024-08-23        7.667          2  [Comedy, Mystery, TV Movie]
# 1  1200387   2017-09-07        6.709        297             [Romance, Drama]
# 2        0   2001-10-14        5.800          6              [Drama, Comedy]
# 3        0   2006-01-01        0.000          0                           []
# 4        0   1980-02-01        6.119         88     [Crime, Drama, Thriller]
#
#             spoken_languages        production_countries
# 0                  [English]                          []
# 1  [Arabic, English, French]             [France, Italy]
# 2                  [English]  [United States of America]
# 3                         []                          []
# 4           [Greek, Italian]            [Cyprus, Greece]
#
# [5 rows x 31 columns]

# %%
#columns_with_lists = []

#for column in df_merged.columns:
   # if df_merged[column].apply(lambda x: isinstance(x, list)).any():
       # columns_with_lists.append(column)

#print(columns_with_lists)

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
columns_to_fix = ['byline.person', 'genres', 'spoken_languages', 'production_countries']

# Create a list of characters to remove
characters_to_remove = ['[', ']', "'", '"']

# Loop through the list of columns to fix
for column in columns_to_fix:
    # Convert the column to a string
    df_merged[column] = df_merged[column].astype(str)


    # Loop through characters to remove
    for char in characters_to_remove:
        df_merged[column] = df_merged[column].str.replace(char, '', regex=False)


# Display the fixed DataFrame
df_merged.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2022/12/15/movies/nell...
# 1  https://www.nytimes.com/2022/06/22/movies/love...
# 2  https://www.nytimes.com/2021/08/26/movies/toge...
# 3  https://www.nytimes.com/2021/06/10/movies/asia...
# 4  https://www.nytimes.com/2019/11/26/movies/quee...
#
#                                              snippet              source  \
# 0  A family archive provides intimate records of ...  The New York Times
# 1  A mother’s final wish leads her daughter to re...  The New York Times
# 2  Sharon Horgan and James McAvoy play a battling...  The New York Times
# 3  This drama about a young single mother and a t...  The New York Times
# 4  Daniel Kaluuya and Jodie Turner-Smith star in ...  The New York Times
#
#                                             keywords  \
# 0  subject: Documentary Films and Programs;person...
# 1  subject: Movies;creative_works: Love & Gelato ...
# 2  subject: Movies;creative_works: Together (Movi...
# 3  subject: Movies;persons: Haas, Shira;persons: ...
# 4  subject: Movies;creative_works: Queen & Slim (...
#
#                    pub_date  word_count  \
# 0  2022-12-15T12:00:04+0000         308
# 1  2022-06-23T03:06:01+0000         288
# 2  2021-08-26T11:00:06+0000         412
# 3  2021-06-10T11:00:15+0000         290
# 4  2019-11-26T17:41:50+0000         799
#
#                                        headline.main headline.kicker  \
# 0  ‘Nelly & Nadine’ Review: An Unlikely Love, an ...            None
# 1  ‘Love & Gelato’ Review: A Young Girl, Transfig...            None
# 2     ‘Together’ Review: Love and Loathing in London            None
# 3  ‘Asia’ Review: Tough Love and an Indecent Prop...            None
# 4             ‘Queen & Slim’ Review: Love on the Run   critic’s pick
#
#   headline.content_kicker                 headline.print_headline  ...  \
# 0                    None                      Nelly &amp; Nadine  ...
# 1                    None                       Love &amp; Gelato  ...
# 2                    None  Love and Loathing in a Blighted London  ...
# 3                    None                                    Asia  ...
# 4                    None          Love Simmers Inside a Cauldron  ...
#
#                                             overview popularity runtime  \
# 0  When an unusual handwritten letter arrives at ...     11.516      84
# 1  Amin, an aspiring screenwriter living in Paris...     14.960     181
# 2  An all-star cast performs the music of one of ...      2.657     105
# 3  Pop-rock supergroup Asia is the focus of this ...      0.001       0
# 4  A woman struggles to keep her stepdaughter fro...     41.432      91
#
#    revenue release_date vote_average vote_count                     genres  \
# 0        0   2024-08-23        7.667          2  Comedy, Mystery, TV Movie
# 1  1200387   2017-09-07        6.709        297             Romance, Drama
# 2        0   2001-10-14        5.800          6              Drama, Comedy
# 3        0   2006-01-01        0.000          0
# 4        0   1980-02-01        6.119         88     Crime, Drama, Thriller
#
#           spoken_languages      production_countries
# 0                  English
# 1  Arabic, English, French             France, Italy
# 2                  English  United States of America
# 3
# 4           Greek, Italian            Cyprus, Greece
#
# [5 rows x 31 columns]

# %%
print(df_merged.columns)
# Out:
# Index(['web_url', 'snippet', 'source', 'keywords', 'pub_date', 'word_count',
#        'headline.main', 'headline.kicker', 'headline.content_kicker',
#        'headline.print_headline', 'headline.name', 'headline.seo',
#        'headline.sub', 'byline.original', 'byline.person',
#        'byline.organization', 'title', 'original_title', 'budget',
#        'original_language', 'homepage', 'overview', 'popularity', 'runtime',
#        'revenue', 'release_date', 'vote_average', 'vote_count', 'genres',
#        'spoken_languages', 'production_countries'],
#       dtype='object')

# %%
# Drop "byline.person" column
# df_merged = df_merged.drop(columns=["byline.person"])
# print(df_merged.head())
# there is no column named 'byline.person' although i saw it earlier... but i will do just an if statement to drop it if found that way i dont lose the points

# Drop the "byline.person" column only if it exists
if "byline.person" in df_merged.columns:
    df_merged = df_merged.drop(columns=["byline.person"])
df_merged
# Out:
#                                               web_url  \
# 0   https://www.nytimes.com/2022/12/15/movies/nell...
# 1   https://www.nytimes.com/2022/06/22/movies/love...
# 2   https://www.nytimes.com/2021/08/26/movies/toge...
# 3   https://www.nytimes.com/2021/06/10/movies/asia...
# 4   https://www.nytimes.com/2019/11/26/movies/quee...
# 5   https://www.nytimes.com/2019/05/16/movies/asak...
# 6   https://www.nytimes.com/2018/11/01/movies/they...
# 7   https://www.nytimes.com/2018/04/26/movies/love...
# 8   https://www.nytimes.com/2018/04/18/movies/goda...
# 9   https://www.nytimes.com/2018/04/18/movies/goda...
# 10  https://www.nytimes.com/2018/04/18/movies/goda...
# 11  https://www.nytimes.com/2017/07/27/movies/the-...
# 12  https://www.nytimes.com/2017/07/27/movies/the-...
# 13  https://www.nytimes.com/2017/07/27/movies/the-...
# 14  https://www.nytimes.com/2017/03/02/movies/love...
# 15  https://www.nytimes.com/2017/03/02/movies/love...
# 16  https://www.nytimes.com/2017/03/02/movies/love...
# 17  https://www.nytimes.com/2017/05/11/movies/houn...
#
#                                               snippet              source  \
# 0   A family archive provides intimate records of ...  The New York Times
# 1   A mother’s final wish leads her daughter to re...  The New York Times
# 2   Sharon Horgan and James McAvoy play a battling...  The New York Times
# 3   This drama about a young single mother and a t...  The New York Times
# 4   Daniel Kaluuya and Jodie Turner-Smith star in ...  The New York Times
# 5   The Japanese director Ryusuke Hamaguchi follow...  The New York Times
# 6   Morgan Neville’s movie tells the tumultuous be...  The New York Times
# 7   In this personal movie, the actress Ashley Bel...  The New York Times
# 8   A portrait of a filmmaker in crisis that might...  The New York Times
# 9   A portrait of a filmmaker in crisis that might...  The New York Times
# 10  A portrait of a filmmaker in crisis that might...  The New York Times
# 11  In war-torn Liberia, Charlize Theron and Javie...  The New York Times
# 12  In war-torn Liberia, Charlize Theron and Javie...  The New York Times
# 13  In war-torn Liberia, Charlize Theron and Javie...  The New York Times
# 14  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 15  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 16  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 17  This feature debut of the Australian filmmaker...  The New York Times
#
#                                              keywords  \
# 0   subject: Documentary Films and Programs;person...
# 1   subject: Movies;creative_works: Love & Gelato ...
# 2   subject: Movies;creative_works: Together (Movi...
# 3   subject: Movies;persons: Haas, Shira;persons: ...
# 4   subject: Movies;creative_works: Queen & Slim (...
# 5   subject: Movies;creative_works: Asako I & II (...
# 6   subject: Documentary Films and Programs;creati...
# 7   creative_works: Love & Bananas: An Elephant St...
# 8   subject: Movies;creative_works: Godard Mon Amo...
# 9   subject: Movies;creative_works: Godard Mon Amo...
# 10  subject: Movies;creative_works: Godard Mon Amo...
# 11  subject: Movies;creative_works: The Last Face ...
# 12  subject: Movies;creative_works: The Last Face ...
# 13  subject: Movies;creative_works: The Last Face ...
# 14  creative_works: Love & Taxes (Movie);persons: ...
# 15  creative_works: Love & Taxes (Movie);persons: ...
# 16  creative_works: Love & Taxes (Movie);persons: ...
# 17  subject: Movies;creative_works: Hounds of Love...
#
#                     pub_date  word_count  \
# 0   2022-12-15T12:00:04+0000         308
# 1   2022-06-23T03:06:01+0000         288
# 2   2021-08-26T11:00:06+0000         412
# 3   2021-06-10T11:00:15+0000         290
# 4   2019-11-26T17:41:50+0000         799
# 5   2019-05-16T11:00:01+0000         547
# 6   2018-11-01T13:56:39+0000         794
# 7   2018-04-26T11:00:01+0000         254
# 8   2018-04-18T23:02:46+0000         937
# 9   2018-04-18T23:02:46+0000         937
# 10  2018-04-18T23:02:46+0000         937
# 11  2017-07-27T20:29:01+0000         280
# 12  2017-07-27T20:29:01+0000         280
# 13  2017-07-27T20:29:01+0000         280
# 14  2017-03-02T21:44:18+0000         246
# 15  2017-03-02T21:44:18+0000         246
# 16  2017-03-02T21:44:18+0000         246
# 17  2017-05-11T20:16:51+0000         280
#
#                                         headline.main headline.kicker  \
# 0   ‘Nelly & Nadine’ Review: An Unlikely Love, an ...            None
# 1   ‘Love & Gelato’ Review: A Young Girl, Transfig...            None
# 2      ‘Together’ Review: Love and Loathing in London            None
# 3   ‘Asia’ Review: Tough Love and an Indecent Prop...            None
# 4              ‘Queen & Slim’ Review: Love on the Run   critic’s pick
# 5   ‘Asako I & II’ Review: Double the Love (and th...   Critic’s Pick
# 6   Review: ‘They’ll Love Me When I’m Dead’ Docume...            None
# 7   Review: In ‘Love & Bananas,’ Uncovering the Pl...            None
# 8   Review: If You Love Godard, You’ll Hate-Watch ...            None
# 9   Review: If You Love Godard, You’ll Hate-Watch ...            None
# 10  Review: If You Love Godard, You’ll Hate-Watch ...            None
# 11  Review: Aid Workers in Love and War in Sean Pe...            None
# 12  Review: Aid Workers in Love and War in Sean Pe...            None
# 13  Review: Aid Workers in Love and War in Sean Pe...            None
# 14  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 15  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 16  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 17  Review: ‘Hounds of Love’ Is Tense and Deadly D...            None
#
#    headline.content_kicker                  headline.print_headline  ...  \
# 0                     None                       Nelly &amp; Nadine  ...
# 1                     None                        Love &amp; Gelato  ...
# 2                     None   Love and Loathing in a Blighted London  ...
# 3                     None                                     Asia  ...
# 4                     None           Love Simmers Inside a Cauldron  ...
# 5                     None  Falling For a Drifter And His Lookalike  ...
# 6                     None             The Legend Behind The Scenes  ...
# 7                     None    Love &amp; Bananas: An Elephant Story  ...
# 8                     None   A Portrait and, for Some, a Hate-Watch  ...
# 9                     None   A Portrait and, for Some, a Hate-Watch  ...
# 10                    None   A Portrait and, for Some, a Hate-Watch  ...
# 11                    None                            The Last Face  ...
# 12                    None                            The Last Face  ...
# 13                    None                            The Last Face  ...
# 14                    None         It’s Inevitable, Mirth and Taxes  ...
# 15                    None         It’s Inevitable, Mirth and Taxes  ...
# 16                    None         It’s Inevitable, Mirth and Taxes  ...
# 17                    None                           Hounds of Love  ...
#
#                                              overview popularity runtime  \
# 0   When an unusual handwritten letter arrives at ...     11.516      84
# 1   Amin, an aspiring screenwriter living in Paris...     14.960     181
# 2   An all-star cast performs the music of one of ...      2.657     105
# 3   Pop-rock supergroup Asia is the focus of this ...      0.001       0
# 4   A woman struggles to keep her stepdaughter fro...     41.432      91
# 5   College student Asako falls in love at first s...     10.257     119
# 6   Williams BMW employed the youngest ever Britis...      0.929     130
# 7   Amin, an aspiring screenwriter living in Paris...     14.960     181
# 8                                                          0.806       8
# 9                                                          0.806       8
# 10                                                         0.806       8
# 11                                                         0.806       8
# 12                                                         0.806       8
# 13                                                         0.806       8
# 14                                                         0.806       8
# 15                                                         0.806       8
# 16                                                         0.806       8
# 17  Featuring astute track-by-track analysis, this...      1.006      90
#
#     revenue release_date vote_average vote_count  \
# 0         0   2024-08-23        7.667          2
# 1   1200387   2017-09-07        6.709        297
# 2         0   2001-10-14        5.800          6
# 3         0   2006-01-01        0.000          0
# 4         0   1980-02-01        6.119         88
# 5         0   2018-09-01        6.799        169
# 6         0   2001-01-01        0.000          0
# 7   1200387   2017-09-07        6.709        297
# 8         0   2022-03-29        0.000          0
# 9         0   2022-03-29        0.000          0
# 10        0   2022-03-29        0.000          0
# 11        0   2022-03-29        0.000          0
# 12        0   2022-03-29        0.000          0
# 13        0   2022-03-29        0.000          0
# 14        0   2022-03-29        0.000          0
# 15        0   2022-03-29        0.000          0
# 16        0   2022-03-29        0.000          0
# 17        0   2009-02-10        8.000          1
#
#                           genres         spoken_languages  \
# 0      Comedy, Mystery, TV Movie                  English
# 1                 Romance, Drama  Arabic, English, French
# 2                  Drama, Comedy                  English
# 3
# 4         Crime, Drama, Thriller           Greek, Italian
# 5                 Drama, Romance        Japanese, English
# 6   History, Documentary, Action                  English
# 7                 Romance, Drama  Arabic, English, French
# 8                      Animation                 Japanese
# 9                      Animation                 Japanese
# 10                     Animation                 Japanese
# 11                     Animation                 Japanese
# 12                     Animation                 Japanese
# 13                     Animation                 Japanese
# 14                     Animation                 Japanese
# 15                     Animation                 Japanese
# 16                     Animation                 Japanese
# 17            Music, Documentary                  English
#
#         production_countries
# 0
# 1              France, Italy
# 2   United States of America
# 3
# 4             Cyprus, Greece
# 5                      Japan
# 6             United Kingdom
# 7              France, Italy
# 8                      Japan
# 9                      Japan
# 10                     Japan
# 11                     Japan
# 12                     Japan
# 13                     Japan
# 14                     Japan
# 15                     Japan
# 16                     Japan
# 17
#
# [18 rows x 30 columns]

# %%
# Delete duplicate rows and reset index
df_merged = df_merged.drop_duplicates().reset_index(drop=True)
# df_merged = df_merged.reset_index(drop=True)
df_merged
# Out:
#                                               web_url  \
# 0   https://www.nytimes.com/2022/12/15/movies/nell...
# 1   https://www.nytimes.com/2022/06/22/movies/love...
# 2   https://www.nytimes.com/2021/08/26/movies/toge...
# 3   https://www.nytimes.com/2021/06/10/movies/asia...
# 4   https://www.nytimes.com/2019/11/26/movies/quee...
# 5   https://www.nytimes.com/2019/05/16/movies/asak...
# 6   https://www.nytimes.com/2018/11/01/movies/they...
# 7   https://www.nytimes.com/2018/04/26/movies/love...
# 8   https://www.nytimes.com/2018/04/18/movies/goda...
# 9   https://www.nytimes.com/2017/07/27/movies/the-...
# 10  https://www.nytimes.com/2017/03/02/movies/love...
# 11  https://www.nytimes.com/2017/05/11/movies/houn...
#
#                                               snippet              source  \
# 0   A family archive provides intimate records of ...  The New York Times
# 1   A mother’s final wish leads her daughter to re...  The New York Times
# 2   Sharon Horgan and James McAvoy play a battling...  The New York Times
# 3   This drama about a young single mother and a t...  The New York Times
# 4   Daniel Kaluuya and Jodie Turner-Smith star in ...  The New York Times
# 5   The Japanese director Ryusuke Hamaguchi follow...  The New York Times
# 6   Morgan Neville’s movie tells the tumultuous be...  The New York Times
# 7   In this personal movie, the actress Ashley Bel...  The New York Times
# 8   A portrait of a filmmaker in crisis that might...  The New York Times
# 9   In war-torn Liberia, Charlize Theron and Javie...  The New York Times
# 10  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 11  This feature debut of the Australian filmmaker...  The New York Times
#
#                                              keywords  \
# 0   subject: Documentary Films and Programs;person...
# 1   subject: Movies;creative_works: Love & Gelato ...
# 2   subject: Movies;creative_works: Together (Movi...
# 3   subject: Movies;persons: Haas, Shira;persons: ...
# 4   subject: Movies;creative_works: Queen & Slim (...
# 5   subject: Movies;creative_works: Asako I & II (...
# 6   subject: Documentary Films and Programs;creati...
# 7   creative_works: Love & Bananas: An Elephant St...
# 8   subject: Movies;creative_works: Godard Mon Amo...
# 9   subject: Movies;creative_works: The Last Face ...
# 10  creative_works: Love & Taxes (Movie);persons: ...
# 11  subject: Movies;creative_works: Hounds of Love...
#
#                     pub_date  word_count  \
# 0   2022-12-15T12:00:04+0000         308
# 1   2022-06-23T03:06:01+0000         288
# 2   2021-08-26T11:00:06+0000         412
# 3   2021-06-10T11:00:15+0000         290
# 4   2019-11-26T17:41:50+0000         799
# 5   2019-05-16T11:00:01+0000         547
# 6   2018-11-01T13:56:39+0000         794
# 7   2018-04-26T11:00:01+0000         254
# 8   2018-04-18T23:02:46+0000         937
# 9   2017-07-27T20:29:01+0000         280
# 10  2017-03-02T21:44:18+0000         246
# 11  2017-05-11T20:16:51+0000         280
#
#                                         headline.main headline.kicker  \
# 0   ‘Nelly & Nadine’ Review: An Unlikely Love, an ...            None
# 1   ‘Love & Gelato’ Review: A Young Girl, Transfig...            None
# 2      ‘Together’ Review: Love and Loathing in London            None
# 3   ‘Asia’ Review: Tough Love and an Indecent Prop...            None
# 4              ‘Queen & Slim’ Review: Love on the Run   critic’s pick
# 5   ‘Asako I & II’ Review: Double the Love (and th...   Critic’s Pick
# 6   Review: ‘They’ll Love Me When I’m Dead’ Docume...            None
# 7   Review: In ‘Love & Bananas,’ Uncovering the Pl...            None
# 8   Review: If You Love Godard, You’ll Hate-Watch ...            None
# 9   Review: Aid Workers in Love and War in Sean Pe...            None
# 10  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 11  Review: ‘Hounds of Love’ Is Tense and Deadly D...            None
#
#    headline.content_kicker                  headline.print_headline  ...  \
# 0                     None                       Nelly &amp; Nadine  ...
# 1                     None                        Love &amp; Gelato  ...
# 2                     None   Love and Loathing in a Blighted London  ...
# 3                     None                                     Asia  ...
# 4                     None           Love Simmers Inside a Cauldron  ...
# 5                     None  Falling For a Drifter And His Lookalike  ...
# 6                     None             The Legend Behind The Scenes  ...
# 7                     None    Love &amp; Bananas: An Elephant Story  ...
# 8                     None   A Portrait and, for Some, a Hate-Watch  ...
# 9                     None                            The Last Face  ...
# 10                    None         It’s Inevitable, Mirth and Taxes  ...
# 11                    None                           Hounds of Love  ...
#
#                                              overview popularity runtime  \
# 0   When an unusual handwritten letter arrives at ...     11.516      84
# 1   Amin, an aspiring screenwriter living in Paris...     14.960     181
# 2   An all-star cast performs the music of one of ...      2.657     105
# 3   Pop-rock supergroup Asia is the focus of this ...      0.001       0
# 4   A woman struggles to keep her stepdaughter fro...     41.432      91
# 5   College student Asako falls in love at first s...     10.257     119
# 6   Williams BMW employed the youngest ever Britis...      0.929     130
# 7   Amin, an aspiring screenwriter living in Paris...     14.960     181
# 8                                                          0.806       8
# 9                                                          0.806       8
# 10                                                         0.806       8
# 11  Featuring astute track-by-track analysis, this...      1.006      90
#
#     revenue release_date vote_average vote_count  \
# 0         0   2024-08-23        7.667          2
# 1   1200387   2017-09-07        6.709        297
# 2         0   2001-10-14        5.800          6
# 3         0   2006-01-01        0.000          0
# 4         0   1980-02-01        6.119         88
# 5         0   2018-09-01        6.799        169
# 6         0   2001-01-01        0.000          0
# 7   1200387   2017-09-07        6.709        297
# 8         0   2022-03-29        0.000          0
# 9         0   2022-03-29        0.000          0
# 10        0   2022-03-29        0.000          0
# 11        0   2009-02-10        8.000          1
#
#                           genres         spoken_languages  \
# 0      Comedy, Mystery, TV Movie                  English
# 1                 Romance, Drama  Arabic, English, French
# 2                  Drama, Comedy                  English
# 3
# 4         Crime, Drama, Thriller           Greek, Italian
# 5                 Drama, Romance        Japanese, English
# 6   History, Documentary, Action                  English
# 7                 Romance, Drama  Arabic, English, French
# 8                      Animation                 Japanese
# 9                      Animation                 Japanese
# 10                     Animation                 Japanese
# 11            Music, Documentary                  English
#
#         production_countries
# 0
# 1              France, Italy
# 2   United States of America
# 3
# 4             Cyprus, Greece
# 5                      Japan
# 6             United Kingdom
# 7              France, Italy
# 8                      Japan
# 9                      Japan
# 10                     Japan
# 11
#
# [12 rows x 30 columns]

# %%
# Export data to CSV without the index

output_folder = r"C:\Users\hdomi\Desktop\UconnAIMLClass\Assigments\data-sourcing-challenge\Myoutput"
file_path = os.path.join(output_folder, 'My_collected_data.csv')
df_merged.to_csv(file_path, index=False)
